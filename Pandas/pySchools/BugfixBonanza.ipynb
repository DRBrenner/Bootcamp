# %%
# Import Dependencies
import pandas as pd

# Create a reference to the CSV and import it into a Pandas DataFrame


csv_path = "Resources/EclipseBugs.csv"
eclipse_df = pd.read_csv(csv_path)
list(eclipse_df)
# Out:
# ['Bug\nID',
#  'Product',
#  'Component',
#  'Assignee',
#  'Status',
#  'Resolution',
#  'Summary',
#  'Changed',
#  'Assignee\nReal\nName',
#  'Classification',
#  'Hardware',
#  'Number of\nComments',
#  'Opened',
#  'OS',
#  'Priority',
#  'Reporter',
#  'Reporter\nReal\nName',
#  'Severity',
#  'Target\nMilestone',
#  'Version',
#  'Votes']

# %%
# Finding the average number of comments per bug
average_comments = eclipse_df["Number of\nComments"].mean()
average_comments
# Out:
# 8.75

# %%
# Grouping the DataFrame by "Assignee"
assignee_group = eclipse_df.groupby("Assignee")

# Count how many of each component Assignees worked on and create DataFrame
assignee_work = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_work
# Out:
#                                                               Component
# Assignee            Component
# Aaron_Ferguson      UI                                               10
# Adam_Schlegel       UI                                                7
# ChrisAustin         User Assistance                                   3
# Claude_Knaus        UI                                               31
#                     Text                                              7
# Curtis_Windatt      UI                                                3
#                     Debug                                             2
#                     API Tools                                         1
# Darin_Swanson       Debug                                           264
#                     Ant                                              33
# James_Moody         Team                                              2
# Karice_McIntyre     UI                                                4
# Kevin_McGuire       Team                                              6
# Lars.Vogel          UI                                                3
# Michael_Rennie      Debug                                            34
#                     API Tools                                         3
# Mike_Wilson         SWT                                               2
# Olivier_Thomann     Core                                             23
#                     API Tools                                         1
#                     APT                                               1
# Platform-UI-Inbox   UI                                                3
#                     User Assistance                                   1
# Randy_Giffen        UI                                                8
# Silenio_Quarti      SWT                                              11
# Szymon.Brandys      UI                                               11
#                     Resources                                         5
# Tod_Creasey         UI                                              453
#                     IDE                                               3
#                     Doc                                               1
#                     Resources                                         1
# ...                                                                 ...
# srikanth_sankaran   Core                                              2
# stderr              Text                                              1
# stephan.herrmann    Core                                              4
# susan               UI                                                9
# sxenos              UI                                               37
#                     Core                                              2
#                     SWT                                               2
#                     IDE                                               1
# szymon.ptaszkiewicz Runtime                                           1
#                     UI                                                1
# t.s.maeder          Search                                            8
#                     UI                                                5
# teicher-bugzilla    Text                                              3
# till_bay            UI                                               21
# tobias_widmer       UI                                               37
#                     Text                                              1
# tom.schindl         UI                                                1
# tomasz.zarna        Compare                                           3
#                     CVS                                               2
#                     Team                                              2
#                     Releng                                            1
#                     UI                                                1
# unknown             UI                                                2
# valentam            Team                                             16
#                     CVS                                               8
#                     Compare                                           6
# veronika_irvine     SWT                                               2
# wassim.melhem       UI                                                3
#                     Update  (deprecated - use RT>Equinox>p2)          1
# zhiyongl            CVS                                               1
#
# [350 rows x 1 columns]

# %%
# Rename the "Component" column to "Component Bug Count"
assignee_work.rename(columns ={"Component": "Component Bug Count"})
# Out:
#                                                               Component Bug Count
# Assignee            Component
# Aaron_Ferguson      UI                                                         10
# Adam_Schlegel       UI                                                          7
# ChrisAustin         User Assistance                                             3
# Claude_Knaus        UI                                                         31
#                     Text                                                        7
# Curtis_Windatt      UI                                                          3
#                     Debug                                                       2
#                     API Tools                                                   1
# Darin_Swanson       Debug                                                     264
#                     Ant                                                        33
# James_Moody         Team                                                        2
# Karice_McIntyre     UI                                                          4
# Kevin_McGuire       Team                                                        6
# Lars.Vogel          UI                                                          3
# Michael_Rennie      Debug                                                      34
#                     API Tools                                                   3
# Mike_Wilson         SWT                                                         2
# Olivier_Thomann     Core                                                       23
#                     API Tools                                                   1
#                     APT                                                         1
# Platform-UI-Inbox   UI                                                          3
#                     User Assistance                                             1
# Randy_Giffen        UI                                                          8
# Silenio_Quarti      SWT                                                        11
# Szymon.Brandys      UI                                                         11
#                     Resources                                                   5
# Tod_Creasey         UI                                                        453
#                     IDE                                                         3
#                     Doc                                                         1
#                     Resources                                                   1
# ...                                                                           ...
# srikanth_sankaran   Core                                                        2
# stderr              Text                                                        1
# stephan.herrmann    Core                                                        4
# susan               UI                                                          9
# sxenos              UI                                                         37
#                     Core                                                        2
#                     SWT                                                         2
#                     IDE                                                         1
# szymon.ptaszkiewicz Runtime                                                     1
#                     UI                                                          1
# t.s.maeder          Search                                                      8
#                     UI                                                          5
# teicher-bugzilla    Text                                                        3
# till_bay            UI                                                         21
# tobias_widmer       UI                                                         37
#                     Text                                                        1
# tom.schindl         UI                                                          1
# tomasz.zarna        Compare                                                     3
#                     CVS                                                         2
#                     Team                                                        2
#                     Releng                                                      1
#                     UI                                                          1
# unknown             UI                                                          2
# valentam            Team                                                       16
#                     CVS                                                         8
#                     Compare                                                     6
# veronika_irvine     SWT                                                         2
# wassim.melhem       UI                                                          3
#                     Update  (deprecated - use RT>Equinox>p2)                    1
# zhiyongl            CVS                                                         1
#
# [350 rows x 1 columns]

# %%
# Find the percentage of bugs overall fixed by each Assignee
total_bugs = assignee_group["Assignee"].count()
bugs_per_user = assignee_group["Assignee"].value_counts()
print(bugs_per_user)

user_bug_percent = pd.DataFrame((bugs_per_user/total_bugs)*100)
user_bug_percent.head()
print(user_bug_percent)
# Out:
# Assignee             Assignee
# Aaron_Ferguson       Aaron_Ferguson          10
# Adam_Schlegel        Adam_Schlegel            7
# ChrisAustin          ChrisAustin              3
# Claude_Knaus         Claude_Knaus            38
# Curtis_Windatt       Curtis_Windatt           6
# Darin_Swanson        Darin_Swanson          297
# James_Moody          James_Moody              2
# Karice_McIntyre      Karice_McIntyre          4
# Kevin_McGuire        Kevin_McGuire            6
# Lars.Vogel           Lars.Vogel               3
# Michael_Rennie       Michael_Rennie          37
# Mike_Wilson          Mike_Wilson              2
# Olivier_Thomann      Olivier_Thomann         25
# Platform-UI-Inbox    Platform-UI-Inbox        4
# Randy_Giffen         Randy_Giffen             8
# Silenio_Quarti       Silenio_Quarti          11
# Szymon.Brandys       Szymon.Brandys          16
# Tod_Creasey          Tod_Creasey            459
# Vikas.Chandra        Vikas.Chandra            3
# a.aswani             a.aswani                 2
# abhishek.kishore     abhishek.kishore         8
# abuzila              abuzila                  1
# achilles-86          achilles-86              1
# achim.demelt         achim.demelt             1
# aclement             aclement                 6
# aeschli              aeschli                627
# aferrazz             aferrazz                 1
# agarcher             agarcher                23
# ahunter.eclipse      ahunter.eclipse          3
# aiproulx             aiproulx                 1
#                                            ...
# rafael.oliveira      rafael.oliveira          1
# raksha.vasisht       raksha.vasisht          16
# rthakkar             rthakkar                 5
# ryan_cooper          ryan_cooper             10
# sarika.sinha         sarika.sinha             1
# sasikanth.bharadwaj  sasikanth.bharadwaj      1
# satyam.kandula       satyam.kandula           1
# serge                serge                    1
# silvio_boehler       silvio_boehler           1
# simon_arsenault      simon_arsenault          6
# snorthov             snorthov                 2
# sonia_dimitrov       sonia_dimitrov           2
# sravankumarl         sravankumarl             1
# srikanth_sankaran    srikanth_sankaran        2
# stderr               stderr                   1
# stephan.herrmann     stephan.herrmann         4
# susan                susan                    9
# sxenos               sxenos                  42
# szymon.ptaszkiewicz  szymon.ptaszkiewicz      2
# t.s.maeder           t.s.maeder              13
# teicher-bugzilla     teicher-bugzilla         3
# till_bay             till_bay                21
# tobias_widmer        tobias_widmer           38
# tom.schindl          tom.schindl              1
# tomasz.zarna         tomasz.zarna             9
# unknown              unknown                  2
# valentam             valentam                30
# veronika_irvine      veronika_irvine          2
# wassim.melhem        wassim.melhem            4
# zhiyongl             zhiyongl                 1
# Name: Assignee, Length: 205, dtype: int64
#                                          Assignee
# Assignee            Assignee
# Aaron_Ferguson      Aaron_Ferguson          100.0
# Adam_Schlegel       Adam_Schlegel           100.0
# ChrisAustin         ChrisAustin             100.0
# Claude_Knaus        Claude_Knaus            100.0
# Curtis_Windatt      Curtis_Windatt          100.0
# Darin_Swanson       Darin_Swanson           100.0
# James_Moody         James_Moody             100.0
# Karice_McIntyre     Karice_McIntyre         100.0
# Kevin_McGuire       Kevin_McGuire           100.0
# Lars.Vogel          Lars.Vogel              100.0
# Michael_Rennie      Michael_Rennie          100.0
# Mike_Wilson         Mike_Wilson             100.0
# Olivier_Thomann     Olivier_Thomann         100.0
# Platform-UI-Inbox   Platform-UI-Inbox       100.0
# Randy_Giffen        Randy_Giffen            100.0
# Silenio_Quarti      Silenio_Quarti          100.0
# Szymon.Brandys      Szymon.Brandys          100.0
# Tod_Creasey         Tod_Creasey             100.0
# Vikas.Chandra       Vikas.Chandra           100.0
# a.aswani            a.aswani                100.0
# abhishek.kishore    abhishek.kishore        100.0
# abuzila             abuzila                 100.0
# achilles-86         achilles-86             100.0
# achim.demelt        achim.demelt            100.0
# aclement            aclement                100.0
# aeschli             aeschli                 100.0
# aferrazz            aferrazz                100.0
# agarcher            agarcher                100.0
# ahunter.eclipse     ahunter.eclipse         100.0
# aiproulx            aiproulx                100.0
# ...                                           ...
# rafael.oliveira     rafael.oliveira         100.0
# raksha.vasisht      raksha.vasisht          100.0
# rthakkar            rthakkar                100.0
# ryan_cooper         ryan_cooper             100.0
# sarika.sinha        sarika.sinha            100.0
# sasikanth.bharadwaj sasikanth.bharadwaj     100.0
# satyam.kandula      satyam.kandula          100.0
# serge               serge                   100.0
# silvio_boehler      silvio_boehler          100.0
# simon_arsenault     simon_arsenault         100.0
# snorthov            snorthov                100.0
# sonia_dimitrov      sonia_dimitrov          100.0
# sravankumarl        sravankumarl            100.0
# srikanth_sankaran   srikanth_sankaran       100.0
# stderr              stderr                  100.0
# stephan.herrmann    stephan.herrmann        100.0
# susan               susan                   100.0
# sxenos              sxenos                  100.0
# szymon.ptaszkiewicz szymon.ptaszkiewicz     100.0
# t.s.maeder          t.s.maeder              100.0
# teicher-bugzilla    teicher-bugzilla        100.0
# till_bay            till_bay                100.0
# tobias_widmer       tobias_widmer           100.0
# tom.schindl         tom.schindl             100.0
# tomasz.zarna        tomasz.zarna            100.0
# unknown             unknown                 100.0
# valentam            valentam                100.0
# veronika_irvine     veronika_irvine         100.0
# wassim.melhem       wassim.melhem           100.0
# zhiyongl            zhiyongl                100.0
#
# [205 rows x 1 columns]

# %%
# Merge the "Percent of Total Bugs Assigned" into the DataFrame
assignee_work = assignee_work.merge(user_bug_percent, on="Assignee")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-90310c6e59b9> in <module>
#       1 # Merge the "Percent of Total Bugs Assigned" into the DataFrame
# ----> 2 assignee_work = assignee_work.merge(user_bug_percent, on="Assignee")
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     831                         if rk is not None:
#     832                             right_keys.append(
# --> 833                                 right._get_label_or_level_values(rk))
#     834                         else:
#     835                             # work-around for merge_asof(right_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1699
#    1700         if self._is_label_reference(key, axis=axis):
# -> 1701             self._check_label_or_level_ambiguity(key, axis=axis)
#    1702             values = self.xs(key, axis=other_axes[0])._values
#    1703         elif self._is_level_reference(key, axis=axis):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _check_label_or_level_ambiguity(self, key, axis)
#    1653                             label_article=label_article,
#    1654                             label_type=label_type)
# -> 1655             raise ValueError(msg)
#    1656
#    1657     def _get_label_or_level_values(self, key, axis=0):
#
# ValueError: 'Assignee' is both an index level and a column label, which is ambiguous.

# %%
# Remove the extra columns
assignee_work = assignee_work[[
    "Assignee", "Percent of Total Bugs", "Component", "Component Bug Count"]]
assignee_work.head()
